# %% [markdown]
# # Praćenje kretanja poljoprivredne mašine - GPS
#
# U ovom primeru opisan je metod za određivanje tačnosti određivanja pozicije poljoprivredne mašine.
#
# Poljoprivredna mašina se uobičajeno koristi u nekoliko sledećih režima:
#  - pravolinijsko kretanje, zadata početna tačka i ugao (oranje, sejanje, prihrana i sejanje)
#  - ponavljanje pravolinijskog kretanja - zadate tačke A i B i udaljenost d
#  - zadato pravolinijsko kretanje deo po deo linija
#  - kretanje prilikom transporta tereta
#
# U periodu testiranja mašine prikupljene su sledeće datoteke:
#
# - 'data/gps_data_1.csv' - kretanje po parceli
# - 'data/gps_data_2.csv' - kretanje po naselju
# - 'data/gps_data_3.csv' - mirovanje
# - 'data/gps_data_4.csv' - mirovanje fix 2
# - 'data/gps_data_5.csv' - mirovanje fix 2 - jako dobro
# - 'data/gps_data_6.csv' - mirovanje fix 2 - jako dobro
# - 'data/gps_data_7.csv' - mirovanje fix 2 - jako dobro
# - 'data/gps_data_8.csv' - mirovanje fix 2 - jako dobro
#
# sadrže merenja po 3000 uzoraka čiji je format dat u nastavku:
#
# ```
# #longitude, latitude, speed, pritisak, ddMMyy, hhmmss.ssss, cog, temperature, fix_status, protok
# #---------------------------------------------------------------------------------
# 19.9908883333	45.4304116667	9.852	22.8	211116	093502.000	297.18	18.8	2	11.70
# 19.9908283333	45.4304333333	9.831	22.6	211116	093504.000	297.02	18.9	2	11.64
# 19.9907666667	45.430455	9.3	22.6	211116	093506.000	299.53	18.9	2	11.64
# 19.99064	45.4305033333	9.26	22.6	211116	093510.000	297.49	19.0	2	12.02
# 19.99058	45.430525	9.373	22.8	211116	093512.000	299.55	19.0	2	11.45
# 19.9905216667	45.4305483333	9.295	22.8	211116	093514.000	296.18	19.0	2	11.39
# 19.9904616667	45.43057	10.027	22.6	211116	093516.000	301.14	19.0	2	11.64
# 19.9904	45.4305916667	10.127	22.9	211116	093518.000	293.80	19.0	2	11.34
#
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.linalg as linalg
# %matplotlib inline
import pandas as pd
from matplotlib.patches import Circle

np.set_printoptions(precision=3)

# %%
def load_data(file_name):
    with open(file_name, 'r') as f:
        data = f.read()
    #print data
    geo = []
    lines = data.split('\n')
    for line in lines:
        parts = line.split('\t')
        if len(parts)>1:
            geo.append(np.array([float(parts[0]), float(parts[1]), float(parts[2])]))
    geo = np.array(geo)
    return geo

# %%
geo = load_data('data/gps_data_1.csv')

# %%
plt.plot(geo[:,0], geo[:,1], color='b', label='Merenja');
plt.legend()
plt.title('Pravolinijsko kretanje masine')
plt.xlabel('lon')
plt.ylabel('lat')
plt.axis('equal')
plt.grid(True)

# %%
speed = geo[:,2]
t = np.arange(0, len(speed))

plt.plot(t, speed, color='b', label='Brzina km/h');
plt.legend()
plt.title('Promena brzine kretanja')
plt.xlabel('t')
plt.ylabel('speed [km/h]')
plt.grid(True)

# %%
#       dlat        dlong
#30°	110.852 km	96.486 km
#45°	111.132 km	78.847 km
klon = 78847
klat = 111132

#lon = klon*geo[15:85,0]
#lat = klat*geo[15:85,1]

#lon = klon*geo[102:172,0]
#lat = klat*geo[102:172,1]

#lon = klon*geo[192:250,0]
#lat = klat*geo[192:250,1]

#lon = klon*geo[270:330,0]
#lat = klat*geo[270:330,1]

lon = klon*geo[350:420,0]
lat = klat*geo[350:420,1]

lon = klon*geo[440:505,0]
lat = klat*geo[440:505,1]


p = np.polyfit(lon, lat, 1)
latModel = np.polyval(p, lon)

errs = (latModel - lat)**2
err = np.mean(errs)
err = np.sqrt(err)
errMax = np.sqrt(np.max(errs))
print 'Razlika odstupanja modela i merenja: '+str(err)+'m'
print 'Max greska je: '+str(errMax)+'m'

dr = np.sqrt((lon[0]-lon[-1])**2+(lat[0]-lat[-1])**2)
print 'Duzina reda je: '+str(dr)+'m'
print 'Max greska na 50m:'+str(100*50*errMax/dr)+'cm' 


plt.plot(lon, lat, color='b', label='Merenja');
plt.plot(lon, latModel, color='r', label='Model');
plt.legend()
plt.title('Pravolinijsko kretanje traktora')
plt.xlabel('lon')
plt.ylabel('lat')
plt.axis('equal')
plt.grid(True)
# Out:
# Razlika odstupanja modela i merenja: 0.0994231267105m
# Max greska je: 0.234516913071m
# Duzina reda je: 343.201755668m
# Max greska na 50m:3.41660421601cm

# %%
speedFilter = geo[15:172,2]>8
sf = 15+ np.where(speedFilter)[0]

plt.plot(geo[sf,0], geo[sf,1], color='b', label='Merenja');
plt.legend()
plt.title('Kretanje po putanji')
plt.xlabel('lon')
plt.ylabel('lat')
plt.axis('equal')
plt.grid(True)

# %%
speed = geo[15:172,2]
t = 2*np.arange(0, len(speed))/60.1

plt.plot(t, speed, color='b', label='Brzina km/h');
plt.legend()
plt.title('Promena brzine kretanja')
plt.xlabel('t')
plt.ylabel('speed [km/h]')
plt.grid(True)

# %%
geo = load_data('data/gps_data_2.csv')

# %%
plt.plot(geo[:,0], geo[:,1], color='b', label='Merenja');
plt.legend()
plt.title('Kretanje po naselju')
plt.xlabel('lon')
plt.ylabel('lat')
plt.axis('equal')
plt.grid(True)

# %%
geo = load_data('data/gps_data_3.csv')

# %%
lonMean = geo[:,0].mean()
latMean = geo[:,1].mean()

plt.plot(geo[:,0], geo[:,1], color='b', label='Merenja');
plt.scatter([lonMean], [latMean], color='r', label='Srednja vrednost');
plt.legend()
plt.title('Mirovanje')
plt.xlabel('lon')
plt.ylabel('lat')
plt.axis('equal')
plt.grid(True)

# %%
import math
from math import sin, cos, atan2, sqrt

def distance(a, b):
    lng1, lat1 = a
    lng2, lat2 = b
    #return distance as meter if you want km distance, remove "* 1000"
    radius = 6371 * 1000 

    dLat = (lat2-lat1) * math.pi / 180
    dLng = (lng2-lng1) * math.pi / 180

    lat1 = lat1 * math.pi / 180
    lat2 = lat2 * math.pi / 180

    val = sin(dLat/2) * sin(dLat/2) + sin(dLng/2) * sin(dLng/2) * cos(lat1) * cos(lat2)    
    ang = 2 * atan2(sqrt(val), sqrt(1-val))
    return radius * ang

def distance2(a,b):
    #       dlat        dlong
    #30°	110.852 km	96.486 km
    #45°	111.132 km	78.847 km
    klon = 78847
    klat = 111132
    dlon = (klon*(a[0]-b[0]))**2
    dlat = (klat*(a[1]-b[1]))**2
    return np.sqrt(dlon+dlat)
    #return dlon+dlat

# %%
import time
d1 = []
d2 = []

start = time.time()
for p in geo[:,0:2]:
    dd1 = distance(p, (lonMean, latMean))
    d1.append(dd1)
timespan = time.time() - start
print timespan 
    
start = time.time()   
for p in geo[:,0:2]:
    dd2 = distance2(p, (lonMean, latMean))
    d2.append(dd2)

timespan = time.time() - start
print timespan 

d1 = np.array(d1)
d2 = np.array(d2)

print d1.mean()
print d2.mean()
# Out:
# 0.0357730388641
# 0.0244488716125
# 10.1641946798
# 10.2176324548

# %%
t = np.arange(0, len(d1))

# %%
plt.plot(t, d1+0.5, color='b', label='d1');
plt.plot(t, d2, color='g', label='d2');
plt.plot(t, 10*(d2-d1), color='r', label='10*(d2-d1)');
plt.legend()
plt.title('Mirovanje')
plt.xlabel('t')
plt.ylabel('err[m]')
plt.grid(True)

# %%
plt.title('Histogram gresaka')
hist, bins = np.histogram(d1, bins=20)
width = 0.7 * (bins[1] - bins[0])
center = (bins[:-1] + bins[1:]) / 2
plt.bar(center, hist, align='center', width=width)
plt.show()

# %%
geo = load_data('data/gps_data_5.csv')

# lon = klon*geo[:,0]
# lat = klat*geo[:,1]
lon = geo[:,0]
lat = geo[:,1]

print geo.shape
# Out:
# (18000, 3)

# %%
lonMean = lon.mean()
latMean = lat.mean()

plt.plot(lon, lat, color='b', label='Merenja');
plt.scatter([lonMean], [latMean], color='r', label='Srednja vrednost');
plt.legend()
plt.title('Mirovanje')
plt.xlabel('lon')
plt.ylabel('lat')
plt.axis('equal')
plt.grid(True)

# %%
d1 = []

for p in geo[:,0:2]:
    dd1 = distance2(p, (lonMean, latMean))
    d1.append(dd1)
d1 = np.array(d1)
print d1.mean()
# Out:
# 0.620848024056

# %%
t = 2*np.arange(0, len(d1))/60.0
plt.plot(t, d1, color='b', label='d1');
plt.legend()
plt.title('Mirovanje')
plt.xlabel('t [min]')
plt.ylabel('err[m]')
plt.grid(True)

# %%
b = []
t = []
d = []

for B in range(10, 1200, 100):
    n = geo.shape[0]
    t.append(B)
    d1 = []
    d2 = []
    for it in range(0, n-B, 10):
        lonB = geo[it:it+B,0]
        latB = geo[it:it+B,1]        
        lonMeanB = lonB.mean()
        latMeanB = latB.mean()                
        dd1 = distance2((lonMeanB, latMeanB), (lonMean, latMean))
        d1.append(dd1)
        ## rastojanja do lokalnog proseka
        dd2 = np.sqrt(klon*klon*(lonMeanB-lonB)**2+
                      klat*klat*(latMeanB-latB)**2)
        d2.append(dd2.mean())        
    d1 = np.array(d1)
    d2 = np.array(d2)
    b.append(d1.mean())
    d.append(d2.mean())
    
b = np.array(b)
d = np.array(d)
t = 2*np.array(t)/60
plt.plot(t, b, color='b', label='d1');
plt.plot(t, d, color='r', label='d');
plt.legend()
plt.title('Mirovanje')
plt.xlabel('velicina bloka [min]')
plt.ylabel('err[m]')
plt.grid(True)

# %% [markdown]
# Period merenja:
# 28.08.2016. 06:30:01.000
# 28.08.2016. 16:33:39.000
#
#
# Crvena linija pokazuje kako se menja vrednost razlike tekuce pozicije od pozicije dobijene usrednjavanjem unutar bloka B. Blok B odredjuje vremenski period unutar kojeg se posmatra relativno odredjivanje pozicije.
#
#
# Relativna pozicija se nije promenila za više od 20cm u vremenskom periodu od 5min.
